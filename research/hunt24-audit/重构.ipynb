# %% [markdown]
# # 重构
#
# ## 目录
# modules/
#   ├── pipelines/                       ◄── [统一算法与管线包]
#   │     ├── __init__.py                ◄── 统一分发器 (run_pipeline)
#   │     ├── stable_pipeline.py         ◄── 常规轨执行器 (StablePipelineRunner)
#   │     ├── experimental_pipeline.py   ◄── 实验双通道轨执行器 (ExperimentalPipelineRunner)
#   │     └── core/                      ◄── [算法内核目录]
#   │           ├── prior_gmm.py          ◄── 原 pg_core.py (常规轨 PriorGMM 内核)
#   │           └── disambiguation/      ◄── 实验轨消歧拟合引擎族 (Bayesian/Blind/Threshold)
#   │                 ├── __init__.py
#   │                 ├── bayesian.py
#   │                 ├── blind.py
#   │                 └── threshold.py
#   ├── workflow.py                      ◄── 纯粹的工作流编排引擎 (Phase 1~6 调度)
#   ├── seed_extractor.py
#   ├── validator.py
#   ├── transformer.py
#   └── ...
